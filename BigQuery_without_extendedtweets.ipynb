# %% [markdown]
# <a href="https://colab.research.google.com/github/zw2497/Twitter_Stream_Processing/blob/master/BigQuery_without_extendedtweets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading https://files.pythonhosted.org/packages/82/39/aebe3ad518513bbb2260dd84ac21e5c30af860cc4c95b32acbd64b9d9d0d/kafka_python-1.4.6-py2.py3-none-any.whl (259kB)
#      |████████████████████████████████| 266kB 4.9MB/s
# Installing collected packages: kafka-python
# Successfully installed kafka-python-1.4.6

# %%
from google.colab import auth
auth.authenticate_user()
print("authorized")
# Out:
# authorized

# %%
from kafka import KafkaProducer, KafkaConsumer
from kafka.errors import KafkaError
from json import dumps, loads
import time
from google.cloud import bigquery
project_id = 'e6820-235222'
client = bigquery.Client(project=project_id)

# %%
consumer = KafkaConsumer(
    'tweepyv1',
     bootstrap_servers=['35.243.144.79:9092'],
     auto_offset_reset='earliest',
     enable_auto_commit=True,
     group_id='my-group313333',
     value_deserializer=lambda x: loads(x.decode('utf-8')))
def make_unicode(input):
    if type(input) != unicode:
        input =  input.decode('utf-8')
        return input
    else:
        return input

# %%
# %%bigquery --project e6820-235222 df
# create table warehouse.tweet_full5(
# created_at string,
# entities_hastages string,
# favorite_count int64,
# id int64,
# id_str string,
# lang string,
# place_country string,
# place_country_code string,
# place_name string,
# quote_count int64,
# quoted_status_entities_hashtages string,
# quoted_status_extended_tweet_entites_hashtags string,
# quoted_status_extended_tweet_full_text string,
# quoted_status_favorite_count int64,
# quoted_status_id_str string,
# reply_count int64,
# retweet_count int64,
# text string,
# timestamp_ms string,
# user_created_at string,
# user_description string,
# user_favourites_count int64,
# user_followers_count int64,
# user_id int64,
# user_id_str string,
# user_listed_count int64,
# user_location string,
# user_name string
# )
# Out:
# Executing query with job ID: f9d96739-be11-42bf-a928-d22c7f3b4260
# Query executing: 0.90s
# ---------------------------------------------------------------------------
# Conflict                                  Traceback (most recent call last)
# <ipython-input-6-233195007cce> in <module>()
# ----> 1 get_ipython().run_cell_magic('bigquery', '--project e6820-235222 df', 'create table warehouse.tweet_full5(\ncreated_at string,\nentities_hastages string,\nfavorite_count int64,\nid int64,\nid_str string,\nlang string,\nplace_country string,\nplace_country_code string,\nplace_name string,\nquote_count int64,\nquoted_status_entities_hashtages string,\nquoted_status_extended_tweet_entites_hashtags string,\nquoted_status_extended_tweet_full_text string,\nquoted_status_favorite_count int64,\nquoted_status_id_str string,\nreply_count int64,\nretweet_count int64,\ntext string,\ntimestamp_ms string,\nuser_created_at string,\nuser_description string,\nuser_favourites_count int64,\nuser_followers_count int64,\nuser_id int64,\nuser_id_str string,\nuser_listed_count int64,\nuser_location string,\nuser_name string\n)')
#
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/magics.py in _cell_magic(line, query)
#     341     job_config.query_parameters = params
#     342     job_config.use_legacy_sql = args.use_legacy_sql
# --> 343     query_job = _run_query(client, query, job_config)
#     344
#     345     if not args.verbose:
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/magics.py in _run_query(client, query, job_config)
#     251         print("\rQuery executing: {:0.2f}s".format(time.time() - start_time), end="")
#     252         try:
# --> 253             query_job.result(timeout=0.5)
#     254             break
#     255         except futures.TimeoutError:
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#    2760             not complete in the given timeout.
#    2761         """
# -> 2762         super(QueryJob, self).result(timeout=timeout)
#    2763         # Return an iterator instead of returning the job.
#    2764         if not self._query_results:
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in result(self, timeout, retry)
#     701             self._begin(retry=retry)
#     702         # TODO: modify PollingFuture so it can pass a retry argument to done().
# --> 703         return super(_AsyncJob, self).result(timeout=timeout)
#     704
#     705     def cancelled(self):
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/future/polling.py in result(self, timeout)
#     120                 the timeout is reached before the operation completes.
#     121         """
# --> 122         self._blocking_poll(timeout=timeout)
#     123
#     124         if self._exception is not None:
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in _blocking_poll(self, timeout)
#    2734     def _blocking_poll(self, timeout=None):
#    2735         self._done_timeout = timeout
# -> 2736         super(QueryJob, self)._blocking_poll(timeout=timeout)
#    2737
#    2738     def result(self, timeout=None, retry=DEFAULT_RETRY):
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/future/polling.py in _blocking_poll(self, timeout)
#      99
#     100         try:
# --> 101             retry_(self._done_or_raise)()
#     102         except exceptions.RetryError:
#     103             raise concurrent.futures.TimeoutError(
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     268                 sleep_generator,
#     269                 self._deadline,
# --> 270                 on_error=on_error,
#     271             )
#     272
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     177     for sleep in sleep_generator:
#     178         try:
# --> 179             return target()
#     180
#     181         # pylint: disable=broad-except
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/future/polling.py in _done_or_raise(self)
#      78     def _done_or_raise(self):
#      79         """Check if the future is done and raise if it's not."""
# ---> 80         if not self.done():
#      81             raise _OperationNotComplete()
#      82
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/job.py in done(self, retry)
#    2721                 project=self.project,
#    2722                 timeout_ms=timeout_ms,
# -> 2723                 location=self.location,
#    2724             )
#    2725
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/client.py in _get_query_results(self, job_id, retry, project, timeout_ms, location)
#     670         # QueryJob.result()). So we don't need to poll here.
#     671         resource = self._call_api(
# --> 672             retry, method="GET", path=path, query_params=extra_params
#     673         )
#     674         return _QueryResults.from_api_repr(resource)
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     380         if retry:
#     381             call = retry(call)
# --> 382         return call()
#     383
#     384     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     268                 sleep_generator,
#     269                 self._deadline,
# --> 270                 on_error=on_error,
#     271             )
#     272
#
# /usr/local/lib/python3.6/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     177     for sleep in sleep_generator:
#     178         try:
# --> 179             return target()
#     180
#     181         # pylint: disable=broad-except
#
# /usr/local/lib/python3.6/dist-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     317
#     318         if not 200 <= response.status_code < 300:
# --> 319             raise exceptions.from_http_response(response)
#     320
#     321         if expect_json and response.content:
#
# Conflict: 409 GET https://www.googleapis.com/bigquery/v2/projects/e6820-235222/queries/f9d96739-be11-42bf-a928-d22c7f3b4260?maxResults=0&timeoutMs=400&location=US: Already Exists: Table e6820-235222:warehouse.tweet_full5

# %%
for line in consumer:
  res = loads(dumps(line))
  favorite_count = int(res[-6]['favorite_count'])
  id = res[-6]['id']
  quote_count= res[-6]['quote_count'] 
  reply_count = res[-6]['reply_count']
  retweet_count = res[-6]['retweet_count']
  user_favourites_count = res[-6]['user']['favourites_count'] 
  user_followers_count =  res[-6]['user']['followers_count']
  user_id =res[-6]['user']['id']
  user_listed_count =  res[-6]['user']['listed_count']
  created_at = str(res[-6]['created_at'])
  
  entities_hastages = []
  for a in res[-6]['entities']['hashtags']:
    entities_hastages.append(a['text'])
  entities_hastages = str(entities_hastages)
  print(type(entities_hastages))
  id_str = str(res[-6]['id'])
  lang = str(res[-6]['lang'])
  place_country = str(res[-6]['place']['country'])
  place_country_code = str(res[-6]['place']['country_code'])
  place_name = str(res[-6]['place']['name'])
#   quoted_status_entities_hashtages = str(res[-6]['quoted_status']['entities']['hashtages'])
#   extended_tweet_entites_hashtags = str(res[-6]['extended_tweet']['entities']['hashtags'])
#   extended_tweet_full_text = str(res[-6]['extended_tweet']['full_text'])
#   extended_tweet_id_str = str(res[-6]['extended_tweet']['id_str'])
  text = str(res[-6]['text'])
  timestamp_ms = str(res[-6]['timestamp_ms'])
  user_created_at = str(res[-6]['user']['created_at'])
  user_description = str(res[-6]['user']['description'])
  user_id_str = str(res[-6]['user']['id_str'])
  user_location = str(res[-6]['user']['location'])
  user_name = str(res[-6]['user']['name'])
#   print(created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,  \
#           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)
#   print(favorite_count, id, quote_count, reply_count, \
#   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count)

  query_job = "INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count, \
  retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name, \
          text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name) \
  VALUES ({}, {}, {}, {}, {}, {}, {}, {}, {}".format(favorite_count, id, quote_count, reply_count, \
  retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count) + ", '"+ created_at + "', \""+ entities_hastages+ "\", '"+ id_str+ "', '"+ lang+ "', '"+ place_country+ "', '"+ place_country_code+ "', '"+ place_name+ "', '"+  \
          text+ "', '"+ timestamp_ms+ "', '"+ user_created_at+ "', '"+ user_description+ "', '"+ user_id_str+ "', '"+ user_location+ "', '"+ user_name+ "')"
  a = str("['GOT']")
#   query_job = "INSERT into warehouse.tweet_full3 (entities_hastages) VALUES ('"+a +"')"

  print(query_job)
  print(entities_hastages)
  client.query(
      query_job,
  )
# Out:
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722010919002112, 0, 0, 0, 5716, 972, 103776611, 4, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722010919002112', 'en', 'United States', 'US', 'Detroit', '@ThePlotInYou @CBryant475 Haha I appreciate you 🙏🏼', '1556512761226', 'Mon Jan 11 06:16:51 +0000 2010', 'Songwriter / Drummer @nearmintoh - vegan - fiancé to @kaituhlin - I sell you @theplotinyou merch', '103776611', 'Columbus, Ohio', 'Michael Cooper')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722010994544641, 0, 0, 0, 13074, 305, 726157134707232768, 0, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722010994544641', 'en', 'United States', 'US', 'Chatsworth', 'Lean wit me rock wit me', '1556512761244', 'Fri Apr 29 21:12:07 +0000 2016', 'sharingan op', '726157134707232768', 'Merica', 'Ethan “Beef” Chastain')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722011069976577, 0, 0, 0, 5273, 447, 1096563334957023232, 0, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722011069976577', 'en', 'United States', 'US', 'Brooklyn', '@MFknowsbest You fasho wasn’t finna run lol', '1556512761262', 'Sat Feb 16 00:14:06 +0000 2019', 'Made with sugar, spice, and everything nice 🧚🏽‍♀️ IG:Sleepy.yellow 🌹JRF🌹', '1096563334957023232', 'California, USA', 'Y E L L O W')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722010516348929, 0, 0, 0, 28880, 1136, 54863147, 6, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722010516348929', 'en', 'United States', 'US', 'Eastchester', 'Not just any crackheads, thems is my crackheads 😭🖤 https://t.co/ejbQiM9aRz', '1556512761130', 'Wed Jul 08 10:58:44 +0000 2009', '22 | NYC ✖️ So no head? 5️⃣1️⃣6️⃣ 🇭🇹|🇨🇺 #BagForRodney', '54863147', 'Crown Heights, BK/Westbury, LI', 'KubanGoodLinks Jr. ☄')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722010683953152, 0, 0, 0, 12186, 1450, 156452641, 5, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122

# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722013414445057, 0, 0, 0, 5323, 358, 885896918, 7, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722013414445057', 'en', 'United States', 'US', 'Los Angeles', 'We gonna have some pretty pretty babiessssssss 🥰', '1556512761821', 'Wed Oct 17 02:48:06 +0000 2012', 'None', '885896918', 'None', 'Gemini.')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722013548830721, 0, 0, 0, 45461, 470, 284660370, 8, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722013548830721', 'en', 'United States', 'US', 'East Orange', 'Just booked another flight. Don’t ask me to go anywhere.', '1556512761853', 'Tue Apr 19 18:23:49 +0000 2011', 'A woman should be two things fabulous and classy - Coco Chanel #FDUgrad #NYLS', '284660370', 'None', 'B Δ K Spring ‘18')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722013477580800, 0, 0, 0, 8248, 56, 337157232, 4, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722013477580800', 'en', 'United States', 'US', 'North Manchester', '@nytimes Please start telling it like it is, instead of beating around the bush. He lies.', '1556512761836', 'Sun Jul 17 15:12:46 +0000 2011', 'Knitter. Reader. Librarian. Lesbian. Maybe I should have that in alphabetical order.', '337157232', 'nomanch in', 'Jeanne Hickling 🏳️‍🌈')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722013951381510, 0, 0, 0, 4821, 638, 194457537, 6, 'Mon Apr 29 04:39:21 +0000 2019', "['GOT']", '1122722013951381510', 'en', 'United States', 'US', 'Vineyard', 'She took off that necklace and was ashes to ashes, dust to dust #GOT', '1556512761949', 'Fri Sep 24 04:48:29 +0000 2010', 'I’m just trying to eat & not gain, and get all of my hair in one selfie #Lobbyist @safeandjust @ncatsuaggies #AggieAlum #EMPAAlum @GGU 💕💚', '194457537', 'Cali, doing Tall Girl things ', 'Andrea')
# ['GOT']
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722014161195008, 0, 0, 0, 1432, 58, 884523849731252229, 0, 'Mon Apr 29 04:39:21 +0000 2019', "[]", '1122722014161195008', 'en', 'Canada', 'CA', 'Toronto', 'i was so tired just an hour ego .. &amp; now i'm tossing and turning 😣', '1556512761999', 'Mon Jul 10 21:24:54 +0000 2017', 'salvadoreña , an aries.', '884523849731252229', 'None', 'aria.ne')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722014391951361, 0, 0, 0, 12566, 591, 1001241827536711685, 0, 'Mon Apr 29 04:39:22 +0000 2019', "[]", '1122722014391951361', 'en', 'United States', 'US', 'Washington', '@pissbongos What if I give u 69$', '1556512762054', 'Mon May 28 23:20:28 +0000 2018', 'everything went numb for the money and the gum', '1001241827536711685', 'District of Columbia, USA', 'Joey')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722014530240518, 0, 0, 0, 13129, 537, 1240434522, 0, 'Mon Apr 29 04:39:22 +0000 2019', "['BattleOfWinterfell']", '1122722014530240518', 'en', 'United States', 'US', 'Brunswick', 'I need anybody in Milledgeville to check on my lady... she just got done watching #BattleOfWinterfell  😩😩😩😩😩😩', '1556512762087', 'Mon Mar 04 04:04:12 +0000 2013', 'history repeats itself and that's just how it goes', '1240434522', 'Brunswick, GA', 'kwil')
# ['BattleOfWinterfell']
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722014656118785, 0, 0, 0, 2190, 148, 456806800, 0, 'Mon Apr 29 04:39:22 +0000 2019', "['ChaseACheckNotANigga']", '1122722014656118785', 'en', 'United States', 'US', 'Memphis', 'A Lil Turn Up Before Work Tomorrow... #ChaseACheckNotANigga https://t.co/ruci92XgKL', '1556512762117', 'Fri Jan 06 17:46:52 +0000 2012', 'I Will Always Leave A Stain On Your Brain 🧠 You Won’t Ever Forget Me 😘', '456806800', 'Houston, TX', 'thelovechild ♍️')
# ['ChaseACheckNotANigga']
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122

# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722024378572800, 0, 0, 0, 437, 552, 237003316, 12, 'Mon Apr 29 04:39:24 +0000 2019', "['GameOfThornes', 'GOT', 'Starks']", '1122722024378572800', 'en', 'United States', 'US', 'Houston', '@GameOfThrones Exhausting! Exhilarating! Epic!
# .
# .
# #GameOfThornes #GOT #Starks https://t.co/LTVnn2Lw1V', '1556512764435', 'Tue Jan 11 21:24:56 +0000 2011', 'As seen on @wsj , Full Time Marketing Strategist , Speaker @mom2summit, Blogger , Runner and Mama of 👶🏻 🐶', '237003316', 'Houston', 'Arushi Garg')
# ['GameOfThornes', 'GOT', 'Starks']
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722026383454208, 0, 0, 0, 1809, 688, 635756751, 1, 'Mon Apr 29 04:39:24 +0000 2019', "[]", '1122722026383454208', 'en', 'United States', 'US', 'Norfolk', 'Couldn’t have been a better weekend @sitw @Pharrell out did himself with this with this one and put VA on the map', '1556512764913', 'Sat Jul 14 21:42:03 +0000 2012', 'VCU22| God first. ✨', '635756751', 'None', 'kiara.')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722026878160896, 0, 0, 0, 39, 230, 216176806, 5, 'Mon Apr 29 04:39:25 +0000 2019', "['VIPassholder']", '1122722026878160896', 'en', 'United States', 'US', 'Florida', '#VIPassholder Event at WDW until 1:00AM @ Disney's Magic Kingdom https://t.co/tE4Sk3YtdX', '1556512765031', 'Mon Nov 15 23:57:53 +0000 2010', 'Dedicated to trying to live a healthy life and enjoy everyday.', '216176806', 'Orlando, FL', 'Dave')
# ['VIPassholder']
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722027629174789, 0, 0, 0, 18451, 2007, 888854272225546241, 1, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722027629174789', 'en', 'United States', 'US', 'Texas', 'i’m literally scared to fall asleep', '1556512765210', 'Sat Jul 22 20:12:27 +0000 2017', '🏳️‍🌈| i like girls who like girls | ♻️🌸💫🦋🌎', '888854272225546241', 'yee haw texas', 'kenna ⚢')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722028375592961, 0, 0, 0, 28067, 1040, 846514116, 4, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722028375592961', 'en', 'United States', 'US', 'San Francisco', 'I only like texting people who make me laugh now', '1556512765388', 'Wed Sep 26 01:06:46 +0000 2012', 'None', '846514116', 'None', 'Troi')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722029218795520, 0, 0, 0, 1273, 288, 556585350, 0, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722029218795520', 'en', 'United States', 'US', 'Downer', 'Mistake 😂😅', '1556512765589', 'Wed Apr 18 03:09:46 +0000 2012', '~Stay Humble~ •Rip Boyer•RIP Toph• Current Product Specialist/Salesman at Turnersville Dodge Chrysler Jeep RAM #Ascension 🌓☯️☮️', '556585350', 'The Dubb, NJ', 'Joe Rizzi')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722029021491200, 0, 0, 0, 4872, 2877, 896061, 287, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722029021491200', 'en', 'United States', 'US', 'Arnold Creek', '@kellyjcallahan thanks, kelly. ♥️😊❗️', '1556512765542', 'Sun Mar 11 02:31:35 +0000 2007', 'pillow fort architect. accidental entrepreneur. designer of things with beautility. professional semiotician. 5 whole feet of fury.', '896061', 'Portland', 'james keller')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722025804574725, 0, 0, 0, 3298, 325, 1528836900, 0, 'Mon Apr 29 04:39:24 +0000 2019', "[]", '1122722025804574725', 'en', 'United States', 'US', 'Atlanta', 'ATL was good today #zoo#stadium#views https://t.co/qrjLnG60zZ', '1556512764775', 'Tue Jun 18 21:10:46 +0000 2013', 'None', '1528836900', 'None', 'Jennifer A')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722029856264192, 0, 0, 0, 5475, 338, 3072227803, 0, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722029856264192', 'en', 'United States', 'US', 'South Euclid', '“they” lmao. y’all used a fake false trending topic to display homophobia and it shows', '1556512765741', 'Wed Mar 11 01:52:50 +0000 2015', 'None', '3072227803', 'South Euclid, OH', 'Caroø')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722030204477440, 0, 0, 0, 64582, 1681, 2267598355, 47, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722030204477440', 'en', 'United States', 'US', 'St George', 'Guy that wrote the books gave up and y’all surprised the folk that make the TV show did? LOLOL!', '1556512765824', 'Sun Dec 29 16:15:27 +0000 2013', 'Lowly convenience store clerk peddling gas, swag, cigs, beer, junk food and wrongthink. Southerner out West.', '2267598355', 'Utah, USA', 'Matthew Dempster')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722030296551424, 0, 0, 0, 9002, 1332, 2719822658, 6, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722030296551424', 'en', 'United States', 'US', 'Walnut Creek', 'im cutting up all week😂', '1556512765846', 'Sat Aug 09 17:54:02 +0000 2014', 'imitation is suicide. A star was born in 99🌟', '2719822658', 'Walnut Creek, CA', '🌟')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722030699384832, 0, 0, 0, 1728, 2889, 2482485900, 19, 'Mon Apr 29 04:39:25 +0000 2019', "[]", '1122722030699384832', 'en', 'United States', 'US', 'Houston', 'Fred said i gotta a lot of growing up to do 😂😂😂😂😂😂😂go home dawg pls ‼️', '1556512765942', 'Wed May 07 17:19:02 +0000 2014', 'i jus miss my brudda', '2482485900', 'Southbaank, TX', '4:21💔')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722030997180421, 0, 0, 0, 11653, 1062, 52892166, 5, 'Mon Apr 29 04:39:26 +0000 2019', "[]", '1122722030997180421', 'en', 'Jamaica', 'JM', 'Jamaica', '@Buckethead619 Don’t talk to me when I come back', '1556512766013', 'Wed Jul 01 23:36:19 +0000 2009', '🇯🇲 22| Psalms 139:14 ✨ Biology Major | Photographer (kaydee_photography) ig: kaycdee', '52892166', 'None', '♍️ kaydee 🇯🇲')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722031424897024, 0, 0, 0, 444, 28, 904201708955459584, 0, 'Mon Apr 29 04:39:26 +0000 2019', "[]", '1122722031424897024', 'en', 'United States', 'US', 'Texas', 'Certainly not making a big deal about it', '1556512766115', 'Sun Sep 03 04:37:41 +0000 2017', 'Politics World News Government & Politics Gov Officials & Agencies Technology News', '904201708955459584', 'Rockdale, TX', 'Robert  Bush')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722031806701568, 0, 0, 0, 48447, 1426, 52254365, 46, 'Mon Apr 29 04:39:26 +0000 2019', "[]", '1122722031806701568', 'en', 'United States', 'US', 'Houston', 'Lmfaooooooooo', '1556512766206', 'Tue Jun 30 01:10:14 +0000 2009', 'I thank God for not giving me what my sins deserve.', '52254365', 'Houston, TX', 'iPopSkittles')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722032616202240, 0, 0, 0, 19985, 509, 769901655403950080, 2, 'Mon Apr 29 04:39:26 +0000 2019', "[]", '1122722032616202240', 'en', 'United States', 'US', 'Virginia Beach', 'I almost lost it when @AndersonPaak started playing Dang! and he showed a photo of Mac Miller during his verse 😭😭😭😭😭', '1556512766399', 'Sun Aug 28 14:17:13 +0000 2016', 'None', '769901655403950080', 'CA✈️NY. ', 'Chronica')
# []
# <class 'str'>
# ...
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722410812276738, 0, 0, 0, 2868, 293, 1093307490526220288, 2, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722410812276738', 'en', 'United States', 'US', 'Edison', '@chrisjosephss That’s what they do', '1556512856568', 'Thu Feb 07 00:36:33 +0000 2019', '4L Featherbed Lane Gang', '1093307490526220288', 'New Jersey, USA', '𝕿𝖍𝖚𝖌 𝖑𝖎𝖋𝖊')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722411441340416, 0, 0, 0, 47360, 575, 27771064, 10, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722411441340416', 'en', 'United States', 'US', 'Pasadena', 'That was the most stressful hr and a half of my life', '1556512856718', 'Tue Mar 31 00:33:05 +0000 2009', '@christielock @carriedweight', '27771064', 'LA', 'k.')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722411479048192, 0, 0, 0, 5559, 338, 100464001, 30, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722411479048192', 'en', 'United States', 'US', 'Los Angeles', '@meelly_y Gotchu', '1556512856727', 'Wed Dec 30 10:24:30 +0000 2009', 'the weirdest regular person. ig: peterkingsbaby', '100464001', 'LA baby 🌴', 'peter kings')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722410220834816, 0, 0, 0, 14056, 266, 111928609, 1, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722410220834816', 'en', 'United States', 'US', 'Seattle', 'When you open twitter before you’ve watched the new GOT episode https://t.co/qv0hdM1KVn', '1556512856427', 'Sat Feb 06 16:45:34 +0000 2010', 'mhm', '111928609', 'Minnesota, USA', 'Clarita')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722411588149249, 0, 0, 0, 17864, 145, 910707926138007552, 0, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722411588149249', 'en', 'United States', 'US', 'Las Cruces', 'For my team down to ride you see it in my eyes', '1556512856753', 'Thu Sep 21 03:31:04 +0000 2017', 'If god is wit me than who can be against me? Nothin like me except me.
# #Litboi$', '910707926138007552', 'None', 'TMC 🗣🏁')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722411638476802, 0, 0, 0, 1377, 268, 4893926645, 5, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722411638476802', 'en', 'United States', 'US', 'Queens', 'Type of bitch lurks on their friend and other friend convos... Lil stupid bitch ! 😂 no life having bitch lol hahah… https://t.co/nkeofMwFG3', '1556512856765', 'Wed Feb 10 03:25:38 +0000 2016', 'Guardian Angel : Eddie Ventura 💟👼🏼 (NYC LAW$) (Spedi Gang) (DTR) 💙💙', '4893926645', 'Bushwick, Brooklyn(Spedi Word)', 'VarVar Suave 💟😎')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722412087238656, 0, 0, 0, 817, 301, 35914397, 1, 'Mon Apr 29 04:40:56 +0000 2019', "['myhero', 'goals']", '1122722412087238656', 'en', 'United States', 'US', 'West Covina', 'Arya said let me get this dick and go kill the night king. #myhero #goals', '1556512856872', 'Tue Apr 28 00:01:36 +0000 2009', 'None', '35914397', 'WCove', 'mamas')
# ['myhero', 'goals']
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722412397772800, 0, 0, 0, 13114, 1154, 50174972, 31, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722412397772800', 'en', 'United States', 'US', 'Alabama', '@neunooga @BlaireCovelli Ding, ding, ding!!!!!', '1556512856946', 'Wed Jun 24 01:47:23 +0000 2009', 'NOLA Living ⚜️Wife, mom to 3, Attorney⚖️ Commercial Realtor, volunteer, ☀️beach lover 🏖 and #IG #influencer Life + Style + Travel  IG- @KatieBrandner', '50174972', 'New Orleans', 'Katie Brandner')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722412829609984, 0, 0, 0, 107, 199, 66869572, 11, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722412829609984', 'en', 'United States', 'US', 'Twin Lakes', '@charmwitch Cut up carrots into thin slices, coat in olive oil and salt and pop in the oven for 10 mins. They becom… https://t.co/52IiESf8Gd', '1556512857049', 'Wed Aug 19 01:33:10 +0000 2009', 'I am a freelance artist out of CO. I work for Gaia Online and I do a few cons a year. I also work as a birth doula.', '66869572', 'Denver, CO', 'Brittany Ngo')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722413731467264, 0, 0, 0, 336, 77, 1074181873260085248, 0, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722413731467264', 'en', 'United States', 'US', 'Flowing Wells', 'I’m thinking of doing Sadness and Joy for Disney/Pixar Day. If anyone wants to be my Joy HMU!!!😭😭', '1556512857264', 'Sun Dec 16 05:58:10 +0000 2018', 'insta: @solinii_', '1074181873260085248', 'United States', 'Sol☀️')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722413874241537, 0, 0, 0, 1661, 6, 1106941836898250753, 0, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722413874241537', 'en', 'United States', 'US', 'Virginia', 'Wow.. just wow', '1556512857298', 'Sat Mar 16 15:34:34 +0000 2019', 'Virginia📍                                                 “I need you in my life like limelight💫”', '1106941836898250753', 'None', 'kyndall jenkins')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722414742441984, 0, 0, 0, 1177, 66, 1072582886837116928, 0, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722414742441984', 'en', 'United States', 'US', 'Oklahoma', 'Shoutout to the guys that do this instead of ignoring their girl👏', '1556512857505', 'Tue Dec 11 20:04:22 +0000 2018', '• EHS Senior • GBRC Queen •', '1072582886837116928', 'Elgin, OK', 'Destiny Tosee©️')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722414771699712, 0, 0, 0, 118, 44, 533280256, 0, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722414771699712', 'en', 'United States', 'US', 'College Station', '@sayanronny Secondly, by this point in time the show wasn't about iron throne anymore. It got larger than life. It… https://t.co/BTBTRtzyry', '1556512857512', 'Thu Mar 22 16:32:22 +0000 2012', 'Graduate Student Research Assistant at Texas A&M University', '533280256', 'College Station, TX', 'Aayushi Bajpayee')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722414989910016, 0, 0, 0, 3201, 614, 70868721, 1, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722414989910016', 'en', 'United States', 'US', 'Mississippi', '@Kccunn10 @okayybree Kc u could’ve vouched for me! 😂😂 she missing a blessing from the good lord on this Sunday', '1556512857564', 'Wed Sep 02 03:15:34 +0000 2009', 'Gemini ♊️, 2️⃣3️⃣ , LEO 👮🏾‍♂️... Lover Not A Fighter', '70868721', 'Starkville, MS', 'D. Clark')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722415405039616, 0, 0, 0, 39682, 702, 277294827, 2, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722415405039616', 'en', 'United States', 'US', 'Lake Charles', 'My eyebrows came out perfect today', '1556512857663', 'Tue Apr 05 02:39:12 +0000 2011', '20 years young♍️|R.I.P Uncle Poody 12/04/16💙|R.I.P Aunt Lottie 12/31/17💜', '277294827', 'Texas, USA', 'Ray. 👅')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722416751468544, 0, 0, 0, 4113, 427, 47103919, 1, 'Mon Apr 29 04:40:57 +0000 2019', "[]", '1122722416751468544', 'en', 'United States', 'US', 'Lakewood', '@kate_white47 @captainkalvis Where did you find this video of me', '1556512857984', 'Sun Jun 14 14:50:29 +0000 2009', '✌🏼❤️⚾️🥃', '47103919', 'Carnegie & Ontario ', 'kell. ૐ')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722417208692738, 0, 0, 0, 798, 312, 1282470547, 3, 'Mon Apr 29 04:40:58 +0000 2019', "[]", '1122722417208692738', 'en', 'United States', 'US', 'Highland Lakes', '@oddcaucasian Whatcha know about that broooooo', '1556512858093', 'Wed Mar 20 06:07:48 +0000 2013', 'UnderArmor and Music is all I need.', '1282470547', 'Birmingham, AL', 'Demetrius Hall')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722417422553090, 0, 0, 0, 22022, 918, 3212735266, 11, 'Mon Apr 29 04:40:58 +0000 2019', "[]", '1122722417422553090', 'en', 'United States', 'US', 'Pulaski', '@erinnmarie615 Thank you !!!!! LOVE U BIG !', '1556512858144', 'Mon Apr 27 12:02:08 +0000 2015', 'I’m the opposite of THAT bitch', '3212735266', 't e nn e ss ee', 'ai$ha')
# []
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722418554888193, 0, 0, 0, 71, 110, 262965946, 17, 'Mon Apr 29 04:40:58 +0000 2019', "['OnTheRoad']", '1122722418554888193', 'en', 'United States', 'US', 'Pittston', 'When I have down time between truck loads I like the visited random gun shops in different cities. #OnTheRoad… https://t.co/aYxkMEp028', '1556512858414', 'Wed Mar 09 03:15:18 +0000 2011', 'None', '262965946', 'None', 'Lajuane D McCLammy')
# ['OnTheRoad']
# <class 'str'>
# INSERT warehouse.tweet_full3 (favorite_count, id, quote_count, reply_count,   retweet_count, user_favourites_count, user_followers_count, user_id, user_listed_count, created_at, entities_hastages, id_str, lang, place_country, place_country_code, place_name,           text, timestamp_ms, user_created_at, user_description, user_id_str, user_location, user_name)   VALUES (0, 1122722411596484610, 0, 0, 0, 12191, 1450, 156452641, 5, 'Mon Apr 29 04:40:56 +0000 2019', "[]", '1122722411596484610', 'en', 'United States', 'US', 'Los Angeles', '😂I AM NOT PMAYING WITH YALL', '1556512856755', 'Thu Jun 17 00:22:47 +0000 2010', 'On A Mission. Atlanta Bred. Morehouse College. Los Angeles📍', '156452641', 'Los Angeles, CA', 'Armani™')
# []

# %%
import uuid
def stream_data(self, table, data, schema):
    # first checks if table already exists. If it doesn't, then create it
    r = self.service.tables().list(projectId=your_project_id,
                                     datasetId=your_dataset_id).execute()
    table_exists = [row['tableReference']['tableId'] for row in
                    r['tables'] if
                    row['tableReference']['tableId'] == table]
    if not table_exists:
        body = {
            'tableReference': {
                'tableId': table,
                'projectId': your_project_id,
                'datasetId': your_dataset_id
            },
            'schema': schema
        }
        self.service.tables().insert(projectId=your_project_id,
                                     datasetId=your_dataset_id,
                                     body=body).execute()

    # with table created, now we can stream the data
    # to do so we'll use the tabledata().insertall() function.
    body = {
        'rows': [
            {
                'json': data,
                'insertId': str(uuid.uuid4())
            }
        ]
    }
    self.service.tabledata().insertAll(projectId=your_project_id),
                                       datasetId=your_dataset_id,
                                       tableId=table,
                                         body=body).execute(num_retries=5)

# %%
message = consumer.poll(timeout_ms=10000, max_records=1)
for key in message.keys():
  if type(key) is not str:
    try:
      message[str(key)] = message[key]
    except:
      try:
        message[repr(key)] =messagemydict[key]
      except:
        pass
    del message[key]
    
a =loads(dumps(message))["TopicPartition(topic='tweepyv1', partition=0)"][-1][-6]
# print(type(loads(dumps(message))["TopicPartition(topic='tweepyv1', partition=0)"][-1][-6]))

# %%
# client.insert_rows("`warehouse.tweet`", str(string), [('tweets','STRING')])

# print(loads(dumps(message)))
query_params = [bigquery.ScalarQueryParameter('tweets', 'STRING', 'message{}'.format(1))]
queryjob = "INSERT warehouse.tweet_info (full_text) VALUES (\""+a +"\")"
print(queryjob)
job_config = bigquery.QueryJobConfig()
job_config.query_parameters = query_params
client.query(
    queryjob,
    job_config=job_config
)
# Out:
# INSERT warehouse.tweet_info (full_text) VALUES ("['GameOfThornes', 'nottoday']")

# %%
for message in consumer:
    key, value = message.key, message.value
#     value.decode()
    print(key)

# %%
a = "['GameOfThornes', 'nottoday']"
print(type(a))
# Out:
# <class 'str'>
